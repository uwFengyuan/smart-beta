# %%
import os
import torch
import torch.nn as nn
import numpy as np
import time
import torch.nn.functional as F
# torch_geometric only used to load the Cora dataset
from torch_geometric.datasets import Planetoid
from torch_geometric.loader import DataLoader
import torch_geometric.utils as U
import torch.optim as optim
import matplotlib.pyplot as plt
import torch_geometric.nn as geom_nn
from models import GATModule, ModifiedGATModule, GCNModule, MLPModule
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
# %matplotlib inline

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

datasetCora = Planetoid("/tmp/Cora", name="Cora")
datasetCiteSeer = Planetoid("/tmp/CiteSeer", name="CiteSeer")
datasetPubMed = Planetoid("/tmp/PubMed", name="PubMed")
datasetlist = [datasetCora, datasetCiteSeer, datasetPubMed]

# %%
class NodeClassification(nn.Module):

    def __init__(self, num_features, hidden_dim, gcn_layers, mlp_layers, num_classes, gnn_act_fn, mlp_act_fn, control_gate, dropout):
      super().__init__()

      self.GNN = None
      self.MLP = None
      
      # GNNModule()
      if control_gate == 'GATMLP':
        self.GNN = GATModule(num_features, hidden_dim, hidden_dim, gcn_layers, gnn_act_fn, dropout)
        self.MLP = MLPModule(hidden_dim, hidden_dim, num_classes, mlp_layers, mlp_act_fn, dropout)
      elif control_gate == 'ModifiedGATMLP':
        self.GNN = ModifiedGATModule(num_features, hidden_dim, hidden_dim, gcn_layers, gnn_act_fn, dropout)
        self.MLP = MLPModule(hidden_dim, hidden_dim, num_classes, mlp_layers, mlp_act_fn, dropout)
      elif control_gate == 'GCNMLP':
        self.GNN = GCNModule(num_features, hidden_dim, hidden_dim, gcn_layers, gnn_act_fn, dropout)
        self.MLP = MLPModule(hidden_dim, hidden_dim, num_classes, mlp_layers, mlp_act_fn, dropout)
      elif control_gate == 'ModifiedGAT':
        self.GNN = ModifiedGATModule(num_features, hidden_dim, num_classes, gcn_layers, gnn_act_fn, dropout)
      elif control_gate == 'GAT':
        self.GNN = GATModule(num_features, hidden_dim, num_classes, gcn_layers, gnn_act_fn, dropout)
      elif control_gate == 'GCN':
        self.GNN = GCNModule(num_features, hidden_dim, num_classes, gcn_layers, gnn_act_fn, dropout)
      elif control_gate == 'MLP':
        self.MLP = MLPModule(num_features, hidden_dim, num_classes, mlp_layers, mlp_act_fn, dropout)

    def forward(self, x, adj_matrix):
      if self.GNN is not None:
        x = self.GNN(x, adj_matrix)

      if self.MLP is not None:
        x = self.MLP(x)

      return x
  
    # Used to reset the weights of the network when training multiple times with
    # different hyperparameters
    def reset_parameters(self):
        def _reset_module_parameters(module):
            for layer in module.children():
                if hasattr(layer, 'reset_parameters'):
                    layer.reset_parameters()
                elif hasattr(layer, 'children'):
                    for child_layer in layer.children():
                        _reset_module_parameters(child_layer)

        _reset_module_parameters(self)

# %%
def train(model, data, adj_matrix, params):
    model.reset_parameters()
    model.train()
    # 定义优化器，通过优化器选择更新的方式
    opt =  optim.Adam(model.parameters(), lr = params["learning_rate"])
    # 定义损失函数，通过损失函数计算梯度
    loss_module = nn.CrossEntropyLoss()

    losses = []
    accuracies = []
    test_accuracies = []
    best_test = 0
    early_stopping = 0
    best_epoch = 0
    
    for e in range(0, params["num_epochs"]):
        # 清空之前的梯度
        opt.zero_grad()
        
        # 得到训练和测试向量
        train_d = data.train_mask
        test_d = data.test_mask

        train_pred = model(data.x, adj_matrix) # 分类预测
        # loss(input, target)
        loss = loss_module(train_pred[train_d], data.y[train_d])
        train_accuracy = (train_pred[train_d].argmax(dim=-1) == data.y[train_d]).sum().float() / train_d.sum()
        test_accuracy = (train_pred[test_d].argmax(dim=1) == data.y[test_d]).sum().float() / test_d.sum()

        #if e % 8 == 0:
        #    print(f"train_loss: {loss}, train_accuracy: {train_accuracy}, and test_accuracy: {test_accuracy}")
        losses.append(loss)
        accuracies.append(train_accuracy)
        test_accuracies.append(test_accuracy)
        if test_accuracy <= best_test:
            early_stopping += 1
        if best_test < test_accuracy:
            best_test = test_accuracy
            best_epoch = e
            early_stopping = 0
        if early_stopping == 10:
            print(f"Best test accuracy is {test_accuracy} with {best_epoch} epochs")
            break

        # 计算梯度
        loss.backward()
        # 更新参数
        opt.step()
    
    return losses, accuracies, test_accuracies, best_test, best_epoch

# %%
for model_name in ['ModifiedGAT', 'GAT', 'MLP', 'GCN']:
    print(f"This model is: {model_name}")
    with open('output.txt', 'w') as f:
        print(f"This model is: {model_name}", file = f)
    for dataset in datasetlist:
        num_nodes = dataset.data.num_nodes
        num_edges = dataset.data.num_edges // 2
        num_features = dataset.num_node_features
        num_classes = dataset.num_classes

        data = dataset[0].to(device)
        adj_matrix = U.to_dense_adj(data.edge_index).squeeze(0)

        params = {
            "hidden_features": 64,
            "num_gcn_layers": 2,
            "num_mlp_layers": 2,
            "learning_rate": 0.005,
            "weight_decay": 0,
            "num_epochs": 300,
            "dropout": 0.2,
        }

        model = NodeClassification(num_features,
                                    params["hidden_features"],
                                    params["num_gcn_layers"],
                                    params["num_mlp_layers"],
                                    num_classes,
                                    gnn_act_fn=nn.ReLU(inplace = True),
                                    mlp_act_fn=nn.ReLU(inplace = True),
                                    control_gate=model_name,
                                    dropout=params['dropout']
        ).to(device)
        timelength_list = []
        best_test_list = []
        for i in range(20):
            start = time.time()
            train_losses, train_accuracies, test_accuracies, best_test, best_epoch = train(model, data, adj_matrix, params)
            end = time.time()
            timelength = end - start

            timelength_list.append(timelength)
            best_test_list.append(best_test)

            #plt.plot([_ for _ in train_accuracies], label = "train_accuracy")
            #plt.plot([_ for _ in test_accuracies], label = "test_accuracy")
            #plt.legend()
            #plt.show()
        print(dataset.name + ": ")
        print(f"Mean best test accuracy: {np.mean(best_test_list)}; SD: {np.std(best_test_list)}")
        print(f"Mean runtime: {np.mean(timelength_list)}; Mean epoches: {best_epoch}")
        with open('output.txt', 'w') as f:
            print(dataset.name + ": ", file = f)
            print(f"Mean best test accuracy: {np.mean(best_test_list)}; SD: {np.std(best_test_list)}", file = f)
            print(f"Mean runtime: {np.mean(timelength_list)}; Mean epoches: {best_epoch}", file = f)
# Out:
# This model is: ModifiedGAT
# Best test accuracy is 0.7540000081062317 with 15 epochs
# Best test accuracy is 0.7540000081062317 with 5 epochs
# Best test accuracy is 0.7570000290870667 with 7 epochs
# Best test accuracy is 0.7649999856948853 with 7 epochs
# Best test accuracy is 0.7680000066757202 with 2 epochs
# Best test accuracy is 0.7559999823570251 with 4 epochs
# Best test accuracy is 0.7310000061988831 with 5 epochs
# Best test accuracy is 0.7540000081062317 with 13 epochs
# Best test accuracy is 0.7649999856948853 with 5 epochs
# Best test accuracy is 0.7509999871253967 with 3 epochs
# Best test accuracy is 0.722000002861023 with 6 epochs
# Best test accuracy is 0.753000020980835 with 4 epochs
# Best test accuracy is 0.7540000081062317 with 4 epochs
# Best test accuracy is 0.734000027179718 with 4 epochs
# Best test accuracy is 0.7369999885559082 with 7 epochs
# Best test accuracy is 0.7570000290870667 with 3 epochs
# Best test accuracy is 0.7509999871253967 with 13 epochs
# Best test accuracy is 0.7540000081062317 with 3 epochs
# Best test accuracy is 0.7409999966621399 with 5 epochs
# Best test accuracy is 0.7289999723434448 with 4 epochs
# Cora:
# Mean best test accuracy: 0.771399974822998; SD: 0.009172778576612473
# Mean runtime: 5.560272121429444
# Best test accuracy is 0.6069999933242798 with 6 epochs
# Best test accuracy is 0.625 with 5 epochs
# Best test accuracy is 0.6290000081062317 with 2 epochs
# Best test accuracy is 0.6050000190734863 with 2 epochs
# Best test accuracy is 0.6159999966621399 with 2 epochs
# Best test accuracy is 0.5929999947547913 with 3 epochs
# Best test accuracy is 0.6159999966621399 with 2 epochs
# Best test accuracy is 0.6150000095367432 with 2 epochs
# Best test accuracy is 0.5920000076293945 with 3 epochs
# Best test accuracy is 0.5960000157356262 with 7 epochs
# Best test accuracy is 0.6140000224113464 with 2 epochs
# Best test accuracy is 0.6039999723434448 with 2 epochs
# Best test accuracy is 0.6169999837875366 with 2 epochs
# Best test accuracy is 0.6079999804496765 with 3 epochs
# Best test accuracy is 0.6119999885559082 with 3 epochs
# Best test accuracy is 0.6079999804496765 with 2 epochs
# Best test accuracy is 0.6150000095367432 with 2 epochs
# Best test accuracy is 0.5929999947547913 with 3 epochs
# Best test accuracy is 0.6140000224113464 with 2 epochs
# Best test accuracy is 0.6129999756813049 with 3 epochs
# CiteSeer:
# Mean best test accuracy: 0.6536000370979309; SD: 0.004476604051887989
# Mean runtime: 6.544430685043335
# Best test accuracy is 0.6919999718666077 with 7 epochs
# Best test accuracy is 0.6919999718666077 with 3 epochs
# Best test accuracy is 0.7429999709129333 with 55 epochs
# Best test accuracy is 0.7210000157356262 with 38 epochs
# Best test accuracy is 0.6880000233650208 with 2 epochs
# Best test accuracy is 0.7310000061988831 with 48 epochs
# Best test accuracy is 0.6859999895095825 with 3 epochs
# Best test accuracy is 0.7319999933242798 with 43 epochs
# Best test accuracy is 0.6980000138282776 with 3 epochs
# Best test accuracy is 0.6859999895095825 with 4 epochs
# Best test accuracy is 0.6869999766349792 with 8 epochs
# Best test accuracy is 0.6949999928474426 with 7 epochs
# Best test accuracy is 0.7009999752044678 with 7 epochs
# Best test accuracy is 0.7009999752044678 with 12 epochs
# Best test accuracy is 0.7039999961853027 with 33 epochs
# Best test accuracy is 0.6959999799728394 with 10 epochs
# Best test accuracy is 0.722000002861023 with 50 epochs
# Best test accuracy is 0.6949999928474426 with 10 epochs
# Best test accuracy is 0.7289999723434448 with 53 epochs
# Best test accuracy is 0.7039999961853027 with 10 epochs
# PubMed:
# Mean best test accuracy: 0.7115500569343567; SD: 0.017063045874238014
# Mean runtime: 586.450001013279
# This model is: GAT
# Best test accuracy is 0.7730000019073486 with 11 epochs
# Best test accuracy is 0.7699999809265137 with 19 epochs
# Best test accuracy is 0.746999979019165 with 17 epochs
# Best test accuracy is 0.7689999938011169 with 6 epochs
# Best test accuracy is 0.7609999775886536 with 13 epochs
# Best test accuracy is 0.7519999742507935 with 18 epochs
# Best test accuracy is 0.7540000081062317 with 8 epochs
# Best test accuracy is 0.7590000033378601 with 12 epochs
# Best test accuracy is 0.75 with 3 epochs
# Best test accuracy is 0.7419999837875366 with 19 epochs
# Best test accuracy is 0.7480000257492065 with 6 epochs
# Best test accuracy is 0.746999979019165 with 4 epochs
# Best test accuracy is 0.7480000257492065 with 15 epochs
# Best test accuracy is 0.7549999952316284 with 2 epochs
# Best test accuracy is 0.7429999709129333 with 12 epochs
# Best test accuracy is 0.7369999885559082 with 5 epochs
# Best test accuracy is 0.7440000176429749 with 4 epochs
# Best test accuracy is 0.7630000114440918 with 21 epochs
# Best test accuracy is 0.746999979019165 with 3 epochs
# Best test accuracy is 0.7429999709129333 with 14 epochs
# Cora:
# Mean best test accuracy: 0.7727999687194824; SD: 0.009677806869149208
# Mean runtime: 4.960485315322876
# Best test accuracy is 0.6359999775886536 with 2 epochs
# Best test accuracy is 0.621999979019165 with 6 epochs
# Best test accuracy is 0.6269999742507935 with 2 epochs
# Best test accuracy is 0.6309999823570251 with 2 epochs
# Best test accuracy is 0.6320000290870667 with 3 epochs
# Best test accuracy is 0.6200000047683716 with 6 epochs
# Best test accuracy is 0.6269999742507935 with 3 epochs
# Best test accuracy is 0.6169999837875366 with 5 epochs
# Best test accuracy is 0.6100000143051147 with 2 epochs
# Best test accuracy is 0.6179999709129333 with 3 epochs
# Best test accuracy is 0.6169999837875366 with 5 epochs
# Best test accuracy is 0.609000027179718 with 3 epochs
# Best test accuracy is 0.6119999885559082 with 4 epochs
# Best test accuracy is 0.6240000128746033 with 5 epochs
# Best test accuracy is 0.5950000286102295 with 3 epochs
# Best test accuracy is 0.6140000224113464 with 4 epochs
# Best test accuracy is 0.6200000047683716 with 2 epochs
# Best test accuracy is 0.6169999837875366 with 2 epochs
# Best test accuracy is 0.6100000143051147 with 8 epochs
# Best test accuracy is 0.6150000095367432 with 3 epochs
# CiteSeer:
# Mean best test accuracy: 0.649399995803833; SD: 0.009609372355043888
# Mean runtime: 5.051243185997009
# Best test accuracy is 0.6959999799728394 with 3 epochs
# Best test accuracy is 0.6930000185966492 with 4 epochs
# Best test accuracy is 0.6899999976158142 with 2 epochs
# Best test accuracy is 0.6899999976158142 with 4 epochs
# Best test accuracy is 0.6959999799728394 with 9 epochs
# Best test accuracy is 0.6809999942779541 with 8 epochs
# Best test accuracy is 0.7429999709129333 with 71 epochs
# Best test accuracy is 0.6899999976158142 with 4 epochs
# Best test accuracy is 0.6850000023841858 with 6 epochs
# Best test accuracy is 0.6940000057220459 with 7 epochs
# Best test accuracy is 0.6990000009536743 with 8 epochs
# Best test accuracy is 0.6899999976158142 with 10 epochs
# Best test accuracy is 0.7440000176429749 with 61 epochs
# Best test accuracy is 0.6840000152587891 with 3 epochs
# Best test accuracy is 0.6840000152587891 with 2 epochs
# Best test accuracy is 0.6909999847412109 with 8 epochs
# Best test accuracy is 0.6919999718666077 with 1 epochs
# Best test accuracy is 0.6940000057220459 with 7 epochs
# Best test accuracy is 0.734000027179718 with 63 epochs
# Best test accuracy is 0.6840000152587891 with 2 epochs
# PubMed:
# Mean best test accuracy: 0.70660001039505; SD: 0.017565308138728142
# Mean runtime: 477.14599549770355
# This model is: MLP
# Best test accuracy is 0.5270000100135803 with 22 epochs
# Best test accuracy is 0.48899999260902405 with 1 epochs
# Best test accuracy is 0.47999998927116394 with 5 epochs
# Best test accuracy is 0.48500001430511475 with 14 epochs
# Best test accuracy is 0.492000013589859 with 5 epochs
# Best test accuracy is 0.4819999933242798 with 10 epochs
# Best test accuracy is 0.47600001096725464 with 11 epochs
# Best test accuracy is 0.47999998927116394 with 19 epochs
# Best test accuracy is 0.49000000953674316 with 1 epochs
# Best test accuracy is 0.49799999594688416 with 8 epochs
# Best test accuracy is 0.5080000162124634 with 12 epochs
# Best test accuracy is 0.4819999933242798 with 10 epochs
# Best test accuracy is 0.4860000014305115 with 9 epochs
# Best test accuracy is 0.4880000054836273 with 4 epochs
# Best test accuracy is 0.49000000953674316 with 0 epochs
# Best test accuracy is 0.49900001287460327 with 6 epochs
# Best test accuracy is 0.460999995470047 with 14 epochs
# Best test accuracy is 0.4790000021457672 with 2 epochs
# Best test accuracy is 0.46700000762939453 with 5 epochs
# Best test accuracy is 0.4779999852180481 with 4 epochs
# Cora:
# Mean best test accuracy: 0.5080999732017517; SD: 0.014501377008855343
# Mean runtime: 0.2318184494972229
# Best test accuracy is 0.5059999823570251 with 7 epochs
# Best test accuracy is 0.4880000054836273 with 1 epochs
# Best test accuracy is 0.49900001287460327 with 12 epochs
# Best test accuracy is 0.48899999260902405 with 16 epochs
# Best test accuracy is 0.4869999885559082 with 3 epochs
# Best test accuracy is 0.5009999871253967 with 7 epochs
# Best test accuracy is 0.49399998784065247 with 13 epochs
# Best test accuracy is 0.49300000071525574 with 2 epochs
# Best test accuracy is 0.49900001287460327 with 11 epochs
# Best test accuracy is 0.5 with 15 epochs
# Best test accuracy is 0.4880000054836273 with 4 epochs
# Best test accuracy is 0.4950000047683716 with 10 epochs
# Best test accuracy is 0.49799999594688416 with 3 epochs
# Best test accuracy is 0.4950000047683716 with 7 epochs
# Best test accuracy is 0.48899999260902405 with 6 epochs
# Best test accuracy is 0.5049999952316284 with 17 epochs
# Best test accuracy is 0.5049999952316284 with 2 epochs
# Best test accuracy is 0.47999998927116394 with 4 epochs
# Best test accuracy is 0.4830000102519989 with 9 epochs
# Best test accuracy is 0.5 with 5 epochs
# CiteSeer:
# Mean best test accuracy: 0.510200023651123; SD: 0.006742400117218494
# Mean runtime: 0.20953149795532228
# Best test accuracy is 0.6800000071525574 with 24 epochs
# Best test accuracy is 0.6790000200271606 with 9 epochs
# Best test accuracy is 0.6790000200271606 with 5 epochs
# Best test accuracy is 0.6809999942779541 with 4 epochs
# Best test accuracy is 0.6690000295639038 with 23 epochs
# Best test accuracy is 0.6890000104904175 with 2 epochs
# Best test accuracy is 0.6710000038146973 with 10 epochs
# Best test accuracy is 0.6830000281333923 with 3 epochs
# Best test accuracy is 0.675000011920929 with 10 epochs
# Best test accuracy is 0.6930000185966492 with 1 epochs
# Best test accuracy is 0.6790000200271606 with 0 epochs
# Best test accuracy is 0.6940000057220459 with 3 epochs
# Best test accuracy is 0.6809999942779541 with 12 epochs
# Best test accuracy is 0.6909999847412109 with 0 epochs
# Best test accuracy is 0.6899999976158142 with 6 epochs
# Best test accuracy is 0.6800000071525574 with 2 epochs
# Best test accuracy is 0.6869999766349792 with 4 epochs
# Best test accuracy is 0.6880000233650208 with 5 epochs
# Best test accuracy is 0.675000011920929 with 1 epochs
# Best test accuracy is 0.6729999780654907 with 8 epochs
# PubMed:
# Mean best test accuracy: 0.6949000358581543; SD: 0.005078383255749941
# Mean runtime: 0.11801291704177856
# This model is: GCN
# Best test accuracy is 0.7440000176429749 with 5 epochs
# Best test accuracy is 0.6949999928474426 with 6 epochs
# Best test accuracy is 0.7409999966621399 with 5 epochs
# Best test accuracy is 0.7490000128746033 with 13 epochs
# Best test accuracy is 0.7319999933242798 with 9 epochs
# Best test accuracy is 0.7400000095367432 with 16 epochs
# Best test accuracy is 0.7110000252723694 with 7 epochs
# Best test accuracy is 0.7239999771118164 with 6 epochs
# Best test accuracy is 0.7210000157356262 with 8 epochs
# Best test accuracy is 0.7260000109672546 with 12 epochs
# Best test accuracy is 0.7770000100135803 with 27 epochs
# Best test accuracy is 0.7559999823570251 with 12 epochs
# Best test accuracy is 0.6949999928474426 with 17 epochs
# Best test accuracy is 0.7459999918937683 with 7 epochs
# Best test accuracy is 0.7279999852180481 with 3 epochs
# Best test accuracy is 0.753000020980835 with 20 epochs
# Best test accuracy is 0.7639999985694885 with 16 epochs
# Best test accuracy is 0.7059999704360962 with 8 epochs
# Best test accuracy is 0.7009999752044678 with 9 epochs
# Best test accuracy is 0.7049999833106995 with 6 epochs
# Cora:
# Mean best test accuracy: 0.7617500424385071; SD: 0.013597335666418076
# Mean runtime: 0.45887782573699953
# Best test accuracy is 0.6000000238418579 with 12 epochs
# Best test accuracy is 0.6240000128746033 with 20 epochs
# Best test accuracy is 0.5979999899864197 with 8 epochs
# Best test accuracy is 0.6029999852180481 with 19 epochs
# Best test accuracy is 0.5789999961853027 with 10 epochs
# Best test accuracy is 0.5950000286102295 with 13 epochs
# Best test accuracy is 0.5889999866485596 with 5 epochs
# Best test accuracy is 0.6079999804496765 with 16 epochs
# Best test accuracy is 0.6010000109672546 with 7 epochs
# Best test accuracy is 0.628000020980835 with 20 epochs
# Best test accuracy is 0.5929999947547913 with 4 epochs
# Best test accuracy is 0.597000002861023 with 8 epochs
# Best test accuracy is 0.5899999737739563 with 11 epochs
# Best test accuracy is 0.6060000061988831 with 7 epochs
# Best test accuracy is 0.6110000014305115 with 38 epochs
# Best test accuracy is 0.6299999952316284 with 38 epochs
# Best test accuracy is 0.609000027179718 with 5 epochs
# Best test accuracy is 0.5979999899864197 with 9 epochs
# Best test accuracy is 0.5740000009536743 with 8 epochs
# Best test accuracy is 0.5759999752044678 with 9 epochs
# CiteSeer:
# Mean best test accuracy: 0.623199999332428; SD: 0.00685274600982666
# Mean runtime: 0.6353300094604493
# Best test accuracy is 0.7739999890327454 with 26 epochs
# Best test accuracy is 0.7440000176429749 with 24 epochs
# Best test accuracy is 0.7409999966621399 with 53 epochs
# Best test accuracy is 0.7710000276565552 with 31 epochs
# Best test accuracy is 0.777999997138977 with 44 epochs
# Best test accuracy is 0.7419999837875366 with 20 epochs
# Best test accuracy is 0.7609999775886536 with 24 epochs
# Best test accuracy is 0.7429999709129333 with 26 epochs
# Best test accuracy is 0.7609999775886536 with 27 epochs
# Best test accuracy is 0.7519999742507935 with 26 epochs
# Best test accuracy is 0.7580000162124634 with 24 epochs
# Best test accuracy is 0.7670000195503235 with 41 epochs
# Best test accuracy is 0.7630000114440918 with 28 epochs
# Best test accuracy is 0.7590000033378601 with 39 epochs
# Best test accuracy is 0.7630000114440918 with 31 epochs
# Best test accuracy is 0.753000020980835 with 27 epochs
# Best test accuracy is 0.7630000114440918 with 26 epochs
# Best test accuracy is 0.7720000147819519 with 33 epochs
# Best test accuracy is 0.7549999952316284 with 28 epochs
# Best test accuracy is 0.7789999842643738 with 34 epochs
# PubMed:
# Mean best test accuracy: 0.7754999399185181; SD: 0.007729813922196627
# Mean runtime: 5.444909203052521
